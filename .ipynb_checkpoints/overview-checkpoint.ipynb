# %%
# %matplotlib inline 
import os
import pandas as pd
import seaborn as sns
import service.predictions as predictions
import pickle
import service.files_combiner
import csv

# %%
# files = [filo for filo in os.listdir("data/NOK") if ".csv" in filo]
# for f in files:
#     service.files_combiner.reformat_csv(f)

# %%
#service.files_combiner.create_raw_data(create=True)

# %%
simulator = pickle.load(open( "data/predictions/simulator.p", "rb" ) )

# %%
df_test= simulator.predictions[0].df
df_test = df_test[4:]

# %%
df_test['pip_observed']=(df_test.observed.iloc[0]-df_test.observed)*10000
df_test['pip_predicted']=(df_test.predicted.iloc[0]-df_test.predicted)*10000
df_test
# Out:
# /home/ramon/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/ramon/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                      observed  predicted  pip_observed  pip_predicted
# 2016-11-01 08:04:00  0.895514   0.896248      0.000000       0.000000
# 2016-11-01 08:05:00  0.895489   0.896178      0.251817       0.701547
# ...

# %%
df_test[['pip_observed','pip_predicted']].plot()

# %%
predictions.plot_predictions(simulator)
