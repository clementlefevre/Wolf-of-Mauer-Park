# %%
# %matplotlib inline 
# %load_ext autoreload
# %autoreload 2
import os
import pandas as pd
import logging
from model.models import Simulator
import service.regressor as regressor
import pickle

import service.files_service as fs
import csv
import datetime

# %%
simulator = Simulator(dt_from='2011-09-29 12:00', dt_to='2011-09-30 12:30', target='Open_Ask_USDNOK', shift=3,fit_model=False,
                     datasource_path='data/merged_no_spread_ultralight.csv',ticks_to_shift=[1,2,3,4,5,10,20,30])
# Out:
# 2016-12-26 15:58:31,907 [INFO ]  new Simulator created

# %%
regressor.dataset(simulator)
# Out:
# 2016-12-26 15:58:31,998 [INFO ]  Start creating the dataset for Open_Ask_USDNOK
# service/train_forecast.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   simulator.target].shift(periods=-simulator.shift)
# 2016-12-26 15:58:32,112 [INFO ]  Finished creating the dataset for Open_Ask_USDNOK

# %%
regressor.fit(simulator)
# Out:
# 2016-12-26 15:58:32,543 [INFO ]  Start fitting the model Targets : Open_Ask_USDNOK : [2011-09-29 12:00:00-2011-09-30 12:30:00]         ticks_to_shift:[1, 2, 3, 4, 5, 10, 20, 30] shift:3
# <function features_weight at 0x7f2f830a9758>

# %%
regressor.predict(simulator)
# Out:
# > /home/ramon/workspace/trade/service/regressor.py(115)predict()
#     113
#     114     Tracer()()
# --> 115     r2 = model.score(dataset['forecast_X'],
#     116                      dataset['observed_y'])
#     117
#
# ipdb> c
# 2016-12-26 15:58:34,607 [INFO ]  R2 = 0.644011731401

# %%
df_t = simulator.predictions.df
df_t['pip_observed']=(df_t.observed -df_t.observed.iloc[0])*10000
df_t['pip_predicted'] = (df_t.predicted-df_t.observed.iloc[0])*10000

# %%
# df_t[['observed','predicted']].plot()
df_t[['pip_observed','pip_predicted']].plot()
