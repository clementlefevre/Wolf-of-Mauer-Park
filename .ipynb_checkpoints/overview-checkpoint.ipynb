# %%
# %matplotlib inline 
import os
import seaborn as sns
import service.predictions as predictions
import pickle

# %%
simulator = pickle.load( open( "data/predictions/simulator.p", "rb" ) )

# %%
simulator.predictions[0].df.head(5)
# Out:
#                      observed  predicted
# 2016-11-01 08:00:00  1.226053   1.224272
# 2016-11-01 08:01:00  1.225969   1.224272
# 2016-11-01 08:02:00  1.226122   1.224272
# 2016-11-01 08:03:00  1.226221   1.224272
# 2016-11-01 08:04:00  1.226383   1.224728

# %%
predictions.plot_predictions(simulator)
